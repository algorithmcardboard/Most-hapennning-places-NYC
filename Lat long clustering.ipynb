# %%
# %matplotlib nbagg
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.basemap import Basemap

m=Basemap(epsg=2263,resolution='h',llcrnrlat = 40.48,llcrnrlon = -74.26,urcrnrlat = 40.92,urcrnrlon = -73.70)
#m=Basemap(projection='omerc',resolution='h',lat_1 = 40.48,lon_1 = -74.26,lat_2 = 40.92,lon_2 = -73.70,
#         height=50000,width=50000, lat_0=40.78, lon_0=-73.98)
#m.arcgisimage(service='World_Topo_Map', server='http://services.arcgisonline.com/ArcGIS/',
              #verbose=True,xpi150
#m.warpimage('http://services.arcgisonline.com/ArcGIS//rest/services/World_Topo_Map/MapServer/export?bbox=-74.26,40.48,-73.7,40.92000000000001&bboxSR=4326&imageSR=4326&size=3000,2357&dpi=150&format=png32&f=image')

m.fillcontinents(color='0.8', lake_color='k', ax=None, zorder=None, alpha=None)
m.drawrivers(color='k')
m.bluemarble()
m.drawcoastlines()
m.drawstates()
plt.show()
# Out:
# <img src="data:image/png;base64,...">
